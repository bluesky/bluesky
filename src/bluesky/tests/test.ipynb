# %%
# Implementation of matplotlib function
import matplotlib.pyplot as plt
import numpy as np

dx, dy = 0.015, 0.05
y, x = np.mgrid[slice(-4, 4 + dy, dy), slice(-4, 4 + dx, dx)]
z = (1 - x / 3.0 + x**5 + y**5) * np.exp(-(x**2) - y**2)
z = z[:-1, :-1]
z_min, z_max = -np.abs(z).max(), np.abs(z).max()

fig, ax = plt.subplots()

c = ax.imshow(
    z,
    cmap="Greens",
    vmin=z_min,
    vmax=z_max,
    extent=[x.min(), x.max(), y.min(), y.max()],
    interpolation="nearest",
    origin="lower",
)

fig.colorbar(c, ax=ax)
ax.set_title("matplotlib.axes.Axes.imshow() Examples")
plt.show()

# %%
import matplotlib.pyplot as plt

from bluesky.callbacks._mpl_image_cross_section import CrossSection, InterpolationEnum

fig = plt.figure()

cs = CrossSection(figure=fig, interpolation=InterpolationEnum.NEAREST)
cs._connect_callbacks()
cs._figure.canvas.set_window_title("window title")
cs._figure.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 7
#       3 from bluesky.callbacks._mpl_image_cross_section import CrossSection, InterpolationEnum
#       5 fig = plt.figure()
# ----> 7 cs = CrossSection(figure=fig, interpolation=InterpolationEnum.NEAREST)
#       8 cs._connect_callbacks()
#       9 cs._figure.canvas.set_window_title("window title")
#
# File /workspaces/bluesky/src/bluesky/callbacks/_mpl_image_cross_section.py:168, in CrossSection.__init__(self, figure, colormap, norm, limit_func, auto_redraw, interpolation, aspect)
#     166 self._image_axes.yaxis.set_major_locator(NullLocator())
#     167 self._imdata = None
# --> 168 self._im = self._image_axes.imshow(
#     169     [[]],
#     170     cmap=self._cmap,
#     171     norm=self._norm,
#     172     interpolation=str(self._interpolation.value),
#     173     aspect=aspect,
#     174 )
# ...

# %%
from bluesky.callbacks.broker import LiveImage

li = LiveImage(data_field_name='test')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 3
#       1 from bluesky.callbacks.broker import LiveImage
# ----> 3 li = LiveImage(data_field_name='test')
#
# File /workspaces/bluesky/src/bluesky/callbacks/broker.py:245, in LiveImage.__init__(self, data_field_name, db, cmap, norm, limit_func, auto_redraw, interpolation, window_title, cross_section)
#     242 fig = plt.figure()
#     243 self.field = data_field_name
#     244 self.cross_section = (
# --> 245     CrossSection(fig, cmap, norm, limit_func, auto_redraw, interpolation)
#     246     if cross_section is None
#     247     else cross_section
#     248 )
#     249 # if window_title:
#     250 # todo that causes error. what is the type of canvas?
#     251 self.cross_section._figure.canvas.set_window_title(window_title)
#
# ...
