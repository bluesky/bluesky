# %%
import matplotlib.pyplot as plt
from ophyd.sim import hw

from bluesky import RunEngine
from bluesky.callbacks.best_effort import BestEffortCallback
from bluesky.plans import scan

# %%
plt.ion()
RE = RunEngine()
bec = BestEffortCallback()
RE.subscribe(bec)

hw = hw()

RE(scan([hw.ab_det], hw.motor, 1, 5, 5))
# Out:
# Transient Scan ID: 1     Time: 2024-10-04 16:49:45
# Persistent Unique Scan ID: 'b78daeb3-c4e2-4516-8170-dc06523fbb39'
# New stream: 'primary'
# +-----------+------------+------------+------------+
# |   seq_num |       time |      motor |      det_a |
# +-----------+------------+------------+------------+
# |         1 | 16:49:45.2 |      1.000 |      0.654 |
# |         2 | 16:49:45.3 |      2.000 |      0.071 |
# |         3 | 16:49:45.3 |      3.000 |      0.279 |
# |         4 | 16:49:45.3 |      4.000 |      0.391 |
# |         5 | 16:49:45.4 |      5.000 |      0.819 |
# +-----------+------------+------------+------------+
# generator scan ['b78daeb3'] (scan num: 1)
# ('b78daeb3-c4e2-4516-8170-dc06523fbb39',)
